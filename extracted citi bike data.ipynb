# %%
import glob
import pandas as pd
import os
import fnmatch

path = os.path.join("C:\\Users\k\Desktop\tableau citi\extracted citi bike data")
rootPath = r"C:\Users\k\Desktop\tableau citi\extracted citi bike data"

# %%
df = pd.concat([pd.read_csv(f) for f in glob.glob(path + "/*.csv")], ignore_index = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-40c71903a7d4> in <module>()
# ----> 1 df = pd.concat([pd.read_csv(f) for f in glob.glob(path + "/*.csv")], ignore_index = True)
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     223                        keys=keys, levels=levels, names=names,
#     224                        verify_integrity=verify_integrity,
# --> 225                        copy=copy, sort=sort)
#     226     return op.get_result()
#     227
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     257
#     258         if len(objs) == 0:
# ...

# %%
glob.glob(path) - returns List[str]
# Out:
#   File "<ipython-input-44-8a1be26fa8da>", line 1
#     glob.glob(path) - returns List[str]
#                                  ^
# SyntaxError: invalid syntax

# %%
allFiles = glob.glob(os.path.join(rootPath, "*.csv"))

list_ = []

for file_ in allFiles:
    df = pd.read_csv(file_,index_col=None, header=0)
    list_.append(df)

frame = pd.concat(list_, axis = 0,sort=False, ignore_index = True)

# %%
list_
# Out:
# [       Trip Duration           Start Time            Stop Time  \
#  0               2084  2016-04-01 00:16:13  2016-04-01 00:50:58
#  1                324  2016-04-01 00:32:48  2016-04-01 00:38:13
#  2                387  2016-04-01 02:00:33  2016-04-01 02:07:00
#  3                140  2016-04-01 02:11:43  2016-04-01 02:14:03
#  4                142  2016-04-01 02:18:01  2016-04-01 02:20:23
#  5                513  2016-04-01 02:26:49  2016-04-01 02:35:22
#  6                 94  2016-04-01 03:32:48  2016-04-01 03:34:22
#  7                474  2016-04-01 04:52:57  2016-04-01 05:00:52
#  8                429  2016-04-01 05:05:23  2016-04-01 05:12:33
#  9                260  2016-04-01 05:07:35  2016-04-01 05:11:56
#  10               419  2016-04-01 05:09:42  2016-04-01 05:16:41
#  11               369  2016-04-01 05:12:27  2016-04-01 05:18:36
#  12               378  2016-04-01 05:18:38  2016-04-01 05:24:56
#  13               494  2016-04-01 05:30:22  2016-04-01 05:38:37
# ...

# %%
frame.head()
# Out:
#    Bike ID  Birth Year  End Station ID  End Station Latitude  \
# 0  24500.0      1979.0          3209.0             40.724176
# 1  24475.0      1954.0          3203.0             40.727596
# 2  24503.0      1975.0          3215.0             40.746730
# 3  24446.0      1981.0          3195.0             40.730743
# 4  24446.0      1981.0          3194.0             40.725340
#
#    End Station Longitude End Station Name  Gender  Start Station ID  \
# 0             -74.050656     Brunswick St     1.0            3203.0
# 1             -74.044247    Hamilton Park     1.0            3202.0
# 2             -74.049251      Central Ave     1.0            3220.0
# 3             -74.063784          Sip Ave     1.0            3194.0
# 4             -74.067622  McGinley Square     1.0            3195.0
#
#    Start Station Latitude  Start Station Longitude    ...    end station name  \
# 0               40.727596               -74.044247    ...                 NaN
# ...

# %%
frame
# Out:
#         Trip Duration           Start Time            Stop Time  \
# 0              2084.0  2016-04-01 00:16:13  2016-04-01 00:50:58
# 1               324.0  2016-04-01 00:32:48  2016-04-01 00:38:13
# 2               387.0  2016-04-01 02:00:33  2016-04-01 02:07:00
# 3               140.0  2016-04-01 02:11:43  2016-04-01 02:14:03
# 4               142.0  2016-04-01 02:18:01  2016-04-01 02:20:23
# 5               513.0  2016-04-01 02:26:49  2016-04-01 02:35:22
# 6                94.0  2016-04-01 03:32:48  2016-04-01 03:34:22
# 7               474.0  2016-04-01 04:52:57  2016-04-01 05:00:52
# 8               429.0  2016-04-01 05:05:23  2016-04-01 05:12:33
# 9               260.0  2016-04-01 05:07:35  2016-04-01 05:11:56
# 10              419.0  2016-04-01 05:09:42  2016-04-01 05:16:41
# 11              369.0  2016-04-01 05:12:27  2016-04-01 05:18:36
# 12              378.0  2016-04-01 05:18:38  2016-04-01 05:24:56
# 13              494.0  2016-04-01 05:30:22  2016-04-01 05:38:37
# ...

# %%
frame.dtypes
# Out:
# Trip Duration              float64
# Start Time                  object
# Stop Time                   object
# Start Station ID           float64
# Start Station Name          object
# Start Station Latitude     float64
# Start Station Longitude    float64
# End Station ID             float64
# End Station Name            object
# End Station Latitude       float64
# End Station Longitude      float64
# Bike ID                    float64
# User Type                   object
# Birth Year                 float64
# Gender                     float64
# tripduration               float64
# starttime                   object
# stoptime                    object
# start station id           float64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id             float64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                     float64
# ...

# %%
allFiles = glob.glob(os.path.join(rootPath, "*.csv"))

list = []

for file_ in allFiles:
    df = pd.read_csv(file_,index_col=None)
    list_.append(df)
dfs = pd.concat(list_, axis = 0,sort=False, ignore_index = True)

# %%
dfs.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0         2084.0  2016-04-01 00:16:13  2016-04-01 00:50:58            3203.0
# 1          324.0  2016-04-01 00:32:48  2016-04-01 00:38:13            3202.0
# 2          387.0  2016-04-01 02:00:33  2016-04-01 02:07:00            3220.0
# 3          140.0  2016-04-01 02:11:43  2016-04-01 02:14:03            3194.0
# 4          142.0  2016-04-01 02:18:01  2016-04-01 02:20:23            3195.0
#
#   Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0      Hamilton Park               40.727596               -74.044247
# 1       Newport PATH               40.727224               -74.033759
# 2  5 Corners Library               40.734961               -74.059503
# 3    McGinley Square               40.725340               -74.067622
# 4            Sip Ave               40.730743               -74.063784
#
#    End Station ID End Station Name  End Station Latitude  ...    \
# ...

# %%
frames = []
for csv in allFiles:  
    with open(csv) as f:
        first_line = f.readline() 
    first_line = first_line.split(',')    
    df = pd.read_csv(csv, skiprows=[0], header=None)
    df['ID'] = first_line[0]
    df['Name'] = first_line[1]
    frames.append(df)


# # concatenate into a single data-frame
#


# Trip Duration              float64
# Start Time                  object
# Stop Time                   object
# Start Station ID           float64
# Start Station Name          object
# Start Station Latitude     float64
# 3    McGinley Square           40.725340              -74.067622
# 4            Sip Ave           40.730743              -74.063784
#
#    Start Station Longitude   End Station ID  End Station Name  \
# 0                     3209     Brunswick St         40.724176
# 1                     3203    Hamilton Park         40.727596
# ...

# %%
df.head()
# Out:
#    Trip Duration           Start Time           Stop Time   Start Station ID  \
# 0           2084  2016-04-01 00:16:13  2016-04-01 00:50:58              3203
# 1            324  2016-04-01 00:32:48  2016-04-01 00:38:13              3202
# 2            387  2016-04-01 02:00:33  2016-04-01 02:07:00              3220
# 3            140  2016-04-01 02:11:43  2016-04-01 02:14:03              3194
# 4            142  2016-04-01 02:18:01  2016-04-01 02:20:23              3195
#
#   Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0      Hamilton Park               40.727596               -74.044247
# 1       Newport PATH               40.727224               -74.033759
# 2  5 Corners Library               40.734961               -74.059503
# 3    McGinley Square               40.725340               -74.067622
# 4            Sip Ave               40.730743               -74.063784
#
#    End Station ID End Station Name  End Station Latitude  \
# ...

# %%
df.describe()
# Out:
#        Trip Duration  Start Station ID  Start Station Latitude  \
# count   8.964040e+05     896404.000000           896404.000000
# mean    7.538169e+02       3234.894533               40.722717
# std     2.032337e+04         98.167456                0.007642
# min     6.100000e+01       3183.000000               40.692640
# 25%     2.350000e+02       3187.000000               40.717733
# 50%     3.510000e+02       3203.000000               40.721525
# 75%     5.940000e+02       3267.000000               40.727224
# max     1.632981e+07       3694.000000               40.752559
#
#        Start Station Longitude  End Station ID  End Station Latitude  \
# count            896404.000000   896404.000000         896404.000000
# mean                -74.046128     3230.065922             40.686602
# std                   0.010809      115.407025              1.204573
# min                 -74.096937       79.000000              0.000000
# ...

# %%
df.to_csv("2016-2018citibikedata", sep='\t', encoding='utf-8')

# %%
df.sort_values(by='Start Time', ascending=True, na_position='first')
# Out:
#        Trip Duration                Start Time                Stop Time   \
# 6776             801  2018-12-31 23:25:49.6090  2018-12-31 23:39:10.7140
# 19476            313  2018-12-31 23:15:43.0680  2018-12-31 23:20:56.8070
# 5577             311  2018-12-31 23:02:34.3020  2018-12-31 23:07:45.6570
# 16733            322  2018-12-31 22:14:36.2470  2018-12-31 22:19:59.0270
# 16732            351  2018-12-31 22:13:51.8670  2018-12-31 22:19:43.3290
# 12822           1374  2018-12-31 19:46:49.6900  2018-12-31 20:09:44.1490
# 14478            196  2018-12-31 19:36:47.4540  2018-12-31 19:40:04.0710
# 15272            102  2018-12-31 19:34:20.2430  2018-12-31 19:36:02.5930
# 4274             281  2018-12-31 19:27:58.5480  2018-12-31 19:32:39.9790
# 4273              82  2018-12-31 19:23:48.6350  2018-12-31 19:25:11.2020
# 11030            657  2018-12-31 19:23:30.4420  2018-12-31 19:34:28.0790
# 4272              73  2018-12-31 19:19:02.3430  2018-12-31 19:20:15.5700
# ...

# %%
df.to_csv('2016-2018citibikedataSorted.csv', index=False,)
